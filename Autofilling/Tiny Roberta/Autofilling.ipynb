# %% [markdown]
# ## Import Model

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline
import re
model_name = "deepset/tinyroberta-squad2"

# %% [markdown]
# ## Sample Contexts and its Answers

# %%
contexts = ["Data Scientist	Herbion Private Limited	Job Summary: Seeking a skilled and motivated Data Scientist to join the Supply Chain Planning Department. Responsible for analyzing large datasets, developing predictive models, and optimizing supply chain processes. Collaborate with cross-functional teams to improve demand forecasting, inventory management, and overall supply chain efficiency. Strong data analysis, statistical modeling, and machine learning skills required. Job Type: Full-time Salary: Rs60,000.00 - Rs80,000.00 per month Ability to commute/relocate: Application Deadline: 30/06/2023 	Rs 60,000 - Rs 80,000 a month	30/06/2023	Karachi	Physical	Full-time	All	Unknown",
            "Freelance Information Technology. (Part Time)	Men's Wear Brand	WEâ€™RE HIRING Freelance Information Technology. (Part Time) As an IT professional you are generally involves managing and storing data using computers, software, databases, networks, and servers. you may write programs, maintain networks, analyze systems, and provide technical support. Requirements: Education: Bachelorâ€™s Degree or equivalent experience in Computer Science, Information Technology, related field. Experience: 3-5 Years IT End User Support / Helpdesk experience Location: Korangi Industrial Area Karachi. Email: goodjobs2022@gmail.com Job Type: Part-timePart-time hours: 24 per week Salary: Rs30,000.00 - Rs35,000.00 per month Ability to Commute: Ability to Relocate: 	Rs 30,000 - Rs 35,000 a month	22/02/2023	Karachi	Physical	Part-time	All	3-5 Year",
            "Data Analyst	The Dynamics Research Consultants	Key Responsibilities: Qualification Job Type: Full-time Salary: Rs50,000.00 - Rs80,000.00 per month Experience: 	Rs 50,000 - Rs 80,000 a month	23/03/2022	Karachi	Physical	Full-time	All	1 Year",
            "IT Support	GENOZONE INTERNATIONAL	looking for Male IT IT Duties and Responsibilities Requirements Timing 6:PM to 3:AM evening Job Types: Part-time, Full-time Salary: Rs25,000.00 - Rs30,000.00 per month Ability to commute/relocate: 	Rs 25,000 - Rs 30,000 a month	25/04/2019	Karachi	Physical	Full-time	All	0-1 Year",
            "Operation/Data Analyst	Pixel Media & Production House	Job Location: Brookes Chowrangi (Godaam Chowrangi), Korangi Industrial Area Job Type: On-Site Salary : 40k to 45k Job Description: We are looking for a strong candidate that forms a key part of our Data team, enabling us in achieving the business goals. The candidate can also carry out all tasks related to Data & Business Intelligence & ML. Operations Analyst will be responsible for analyzing and interpreting large amounts of data. You will commonly work with a variety of different types of data, including customer care, sales, Operations, supply chain etc. Job Responsibilities: A Operations Analyst typically has a wide range of responsibilities, which can include: Requirement: What you get in return: As a team member, youâ€™ll work in a fast-paced corporate environment and make an impact on our business, contributing to the success of our company. Through on-the-job training and learning opportunities, you will develop valuable skills for the future. Job Type: Full-time Salary: Rs40,000.00 - Rs45,000.00 per month Ability to commute/relocate: Application Question(s): Education: 	Rs 40,000 - Rs 45,000 a month	22/01/2022	Karachi	Physical	Full-time	All	1-2 Year",
            "Data Analyst	Garments company	We are seeking a talented â€œData Analystâ€ to join Apparel Brand to drive analyzing, reporting, and growth. The ideal candidate will be passionate about the Brands Industry. Responsibilities: Analytical/Data Skills: Qualifications: Gender: Male (Preferred) Location: I.I Chundrigar Road Karachi. Salary: Rs. 75K to 125K Interested candidates may send their resumes to hrgoodjob2023@gmail.com Only shortlisted candidate will be called for interview Job Type: Full-time Salary: Rs75,000.00 - Rs125,000.00 per month Ability to Commute: Ability to Relocate: 	Rs 75,000 - Rs 125,000 a month	25/03/2023	Karachi	Physical	Full-time	Male	2 YearData Analyst	Garments company	We are seeking a talented â€œData Analystâ€ to join Apparel Brand to drive analyzing, reporting, and growth. The ideal candidate will be passionate about the Brands Industry. Responsibilities: Analytical/Data Skills: Qualifications: Gender: Male (Preferred) Location: I.I Chundrigar Road Karachi. Salary: Rs. 75K to 125K Interested candidates may send their resumes to hrgoodjob2023@gmail.com Only shortlisted candidate will be called for interview Job Type: Full-time Salary: Rs75,000.00 - Rs125,000.00 per month Ability to Commute: Ability to Relocate: 	Rs 75,000 - Rs 125,000 a month	25/03/2023	Karachi	Physical	Full-time	Male	2 Year",
            "Data Engineer	Dolphin Analytics	Job description Requirements Technical expertise in data models, database design development, and data miningCreating integrated data pipelines and APIsExperience building reporting/data visualizationsSolid knowledge of SQL and Data WarehousingExperience in Python Scraping Qualifications 1 year to 3 years experience in a Data Science roleBachelor in Computer Science/ Computer Engineering or MathematicsExcellent verbal and written communication skills (Toastmasters will be given preference) Job Types: Full-time, ContractContract length: 12 months Salary: Rs50,000.00 - Rs130,000.00 per month Ability to commute/relocate: Education: 	Rs 50,000 - Rs 130,000 a month	27/04/2021	Karachi	Physical	Full-time	All	1-3 Year",
            "Data Analyst	Cooperative Computing	Cooperative Computing (CC):â€¯ We accelerate growth minded companies into the automated economy. The business market is in rapid change, with consumer behavior placing significantly high expectations on businesses at every phase in the client experience.â€¯ Each day, we experience a company dramatically shifting â€œindustry normsâ€ and in many cases, removing historical market leaders from their market leading position.â€¯ These elements create extraordinary opportunities for our team members to excel. CC delivers superior client experiences as the premier digital enabler of growth minded enterprises enabling their rapid growth and ensuring their sustainable and smooth transition into the Automated Economy. Our team is passionate in delivering client value and is fanatical in how we go about ensuring we deliver extraordinary business results for our clients.â€¯ We are committed to growing as individuals first, becoming the best version of ourselves in who we have been created to be.â€¯ We take responsibility in our thoughts and actions, know our purpose and our end in mind and put these first in our lives. The Role: To advance our mission of inspiring greatness and transforming the lives of others, our Data Analyst will play a key role in collecting, analyzing, and interpreting data to provide valuable insights that drive informed business decisions. Your responsibilities will include data collection, cleaning, analysis, visualization, and reporting. You will work with various data sources, tools, and databases to ensure accurate and reliable data. Your ability to identify patterns, create visualizations, and effectively communicate findings to stakeholders will contribute to data-driven decision-making within the organization. Capabilities (Key Behaviors): The Data Analyst is expected to have: Results: By leveraging these capabilities, the Data Analyst will aim to achieve: Job Type: Full-time Experience: Application Deadline: 29/09/2023 	Unknown	29/09/2023	Karachi	Physical	Full-time	All	0-1 Year",
            "BI Analyst	HubDigit Pvt Ltd.	As a Business Intelligence Analyst, you will play a pivotal role in translating data into actionable insights that drive strategic decisions. Leveraging your analytical skills and business acumen, you'll collaborate with cross-functional teams to deliver valuable data-driven solutions. Responsibilities: - Gather and analyze business requirements to develop data-driven insights. - Design and create interactive dashboards and reports for various stakeholders. - Identify trends, patterns, and opportunities within complex datasets. - Collaborate with data engineers to ensure seamless data integration and quality. - Present findings and recommendations to both technical and non-technical audiences. - Monitor key performance indicators and provide proactive insights. - Participate in the design and development of data models and ETL processes. - Stay updated on industry best practices and emerging trends in BI and analytics. Qualifications: - Bachelor's degree in Business, Computer Science, Analytics, or a related field. - Proven experience as a Business Intelligence Analyst or similar role. - Strong proficiency in data visualization tools such as Tableau, Power BI, or similar. - Proficiency in SQL for data manipulation and extraction. - Analytical mindset with the ability to translate data into actionable insights. - Excellent communication skills to convey complex findings clearly. - Familiarity with data warehousing concepts and ETL processes. - Detail-oriented and able to work both independently and collaboratively. - Knowledge of programming languages (Python, R) is a plus. - Prior experience with cloud platforms and big data technologies is advantageous. Job Type: Full-time Salary: From Rs100,000.00 per month 	Rs 100,000 a month	15/04/2023	Karachi	Physical	Full-time	All	0-1 Year	Business Intelligence, Data Visualization, SQL Analysis, Data Integration, Python",
            "IT Support Executive	Lime Software Logics (SMC-PVT) Limited	Responsible for the maintenance, configuration, and reliable operation of the organization's computer systems and network infrastructure. This role involves providing technical support to end-users, troubleshooting hardware and software issues, and ensuring the smooth functioning of the IT environment. The IT/Network Officer also assists in the implementation of IT projects and security measures to safeguard the organization's data and systems. Tasks: Qualifications and Requirements: Job Type: Full-time Salary: Rs45,000.00 - Rs55,000.00 per month Ability to commute/relocate: Experience: Shift availability: 	Rs 45,000 - Rs 55,000 a month	25/03/2023	Karachi	Physical	Full-time	All	2-3 Year	IT Infrastructure Management, Network Administration, Technical Support, IT Project Implementation, Data Security Measures",
            "Secretary/Personal Assistant	M.S.Ajmal Business Consultant	Personal Assistant with excellent computing background to Director who is a multiple business owner in the UK and UAE. The sectors of the business range from IT Software development to construction, property development and investments. The successful candidate for this position will have experience handling high-level tasks, an ability to maintain confidentiality, an affinity for multi-tasking, and a professional work ethic. Additionally, the Personal Assistant will have to be well organised and have very strong communication skills in English Language (Spoken and Written). Key skills and experience required: Key responsibilities; Salary to be negotiated subject to applicants experience. Please get in touch with CV, cover letter and availability for interview. Job Type: Full-time Salary: Minimum 60,000.00 PKR per month with Bonus scheme Schedule: Supplemental pay types: Work Location: This is a work from home position (Remote) Job Type: Full-time Salary: From Rs60,000.00 per month 	Rs 60,000 a month	27/01/2023	Karachi	Remote	Full-time	All	1-2 Year	Multi-sector Business Management, IT Software Development, Construction, Property Development, Investments",
            "Data Entry Executive	Aykays	Aykays is looking for a fresh candidates preferably with a computer science background to work on our in-house projects that require good English writing skills as well as speed and enthusiasm. We need someone who is:CreativeRegularPunctualProficient in EnglishSelf-motivated with strong work ethics. Fresh grads are also encouraged to apply for internships. The internships will be paid with a stipend of PKR 20000 + up to 15,000 and more commission per month. Timings: 3pm to 12am OR 10pm to 7am Job Types: Full-time, Part-time, Internship, Contract, CommissionContract length: 3 monthsPart-time hours: 36 per week Salary: Rs20,000.00 per month Ability to commute/relocate: 	Rs 20,000 a month	25/05/2023	Karachi	Physical	Full-time	All	0-1 Year	Data Analyst, English Writing, Project Management",
            "Production Support Officer	GSK	 Job Purpose  To work on Tablet Blister/Tablet Packaging area ensuring the required output and complying with applicable GMP, EHS and Regulatory standards.   Education, Experience & Skills:  Diploma/ BTech  Minimum 2-3 years in relevant role  QMS & EHS training   Key responsibilities:  Ensure Safety of the area with Zero Waste Promotions and ZAP & ZIP reporting.  Keep up-to-date production, downtime, changeover, preventive maintenance, and other records on daily basis for Tablet Blister/Tablet packaging.  Hands on experience in Tablet, blister and cartoning operation.  Able to troubleshoot and rectify the breakdown on Tablet Blister and Cartoning Machine.  Expert in product changeover of different format at blister and cartoning machine.  Suggest and implement measures to improve the machine efficiency OEE.  Ensure all production floorâ€™s KPI are being maintained and met. e.g., Adherence to Daily OEE target and Adherence to conformance of daily plan.  Ensure the GMP (proper labelling, IPC etc.) and EHS (Zero access, LOTO etc.) compliance during operation.  Ensure cost efficient way, right first-time operation, minimizing changeovers and avoiding wastages.  Maintain complete record of the respective machine e.g., daily working Logbooks, Maintenance Record, Cleaning and Changeover Record etc.  Ensure Data integrity compliance and improve the DI control (ALCOA principle) at Packaging.  Ensure all Blister/Tablet packaging operation related End to End production SAP transactions are punched timely.  Why Us?  GSK is a global biopharma company with a special purpose â€“ to unite science, technology and talent to get ahead of disease together â€“ so we can positively impact the health of billions of people and deliver stronger, more sustainable shareholder returns â€“ as an organization where people can thrive. Getting ahead means preventing disease as well as treating it, and we aim to positively impact the health of 2.5 billion people by the end of 2030.   Our success absolutely depends on our people. While getting ahead of disease together is about our ambition for patients and shareholders, itâ€™s also about making GSK a place where people can thrive. We want GSK to be a workplace where everyone can feel a sense of belonging and thrive as set out in our Equal and Inclusive Treatment of Employees policy. Weâ€™re committed to being more proactive at all levels so that our workforce reflects the communities we work and hire in, and our GSK leadership reflects our GSK workforce.   Contact information:  You may apply for this position online by selecting the Apply now button.   Important notice to Employment businesses/ Agencies  GSK does not accept referrals from employment businesses and/or employment agencies in respect of the vacancies posted on this site. All employment businesses/agencies are required to contact GSK's commercial and general procurement/human resources department to obtain prior written authorization before referring any candidates to GSK. The obtaining of prior written authorization is a condition precedent to any agreement (verbal or written) between the employment business/ agency and GSK. In the absence of such written authorization being obtained any actions undertaken by the employment business/agency shall be deemed to have been performed without the consent or contractual agreement of GSK. GSK shall therefore not be liable for any fees arising from such actions or any fees arising from any referrals by employment businesses/agencies in respect of the vacancies posted on this site. 	Unknown	02/03/2023	Karachi	Physical	Full-time	All	0-1 Year	Pharmaceutical Manufacturing",
            "Data Analyst (CRM)	Domino's Pizza Pakistan	Location: You will work in our Karachi office for an organization based in Saudi Arabia (KSA). Job Title â€“ Data Analytics Specialist (CRM) Objective â€“ The objective of the data analytics specialist role is to develop and implement customer segmentations, campaign analysis framework, run customer behavioral analysis and derive insights that would help to drive business decisions. The role involves leveraging data analysis and visualization tools to extract actionable insights, optimize processes and drive informed decision making within the organization. Responsibilities: Requirements: Job Type: Full-time Education: Experience: Application Deadline: 30/09/2023 	Full-time	30/09/2023	Karachi	Physical	Full-time	All	2-3 Year	Data Analytics, Customer Segmentation, Campaign Analysis, Behavioral Analysis, Decision Making Insights",
            "Project Trainee	GSK	 Job Purpose  Implement EHS programs based on EHS management system in order to achieve the GSK Strategic Deployment Objectives in consideration of EHS policy and vision.   Education, Experience & Skills:  B.E (Engineering)/ Masters (Environmental Sciences)  EHS Certification  At least 1 year experience with managing EHS and different domains related to Health and Safety in an organization  Must possess knowledge of industry standards and codes related to occupational safety and design  Good communication and presentation skills   Key responsibilities:  Ensure compliance to local industry and government regulations, GSK standards, procedures, guidelines at the site and ensure continuous EHS improvement in all work processes.  Ensure compliance of the releases to environment from the facilityâ€™s operations; in accordance with applicable regulatory limits and other relevant environmental discharge criteria. Compilation and data analysis.  Implement controls related to Process safety, permit to work and contractor management at site.  Carry out EHS related trainings for down the line staff based on their training needs.  Conduct and assist departments in carrying out risk assessments and L-1 audits.  Assist the EHS Manager and Site for implementation of safety initiatives and monitor progress against them at the site  Participate in different meetings and forums and provide useful inputs regarding existing EHS issues, and requirements, to achieve the corporate EHS goals.  Conduct EHS internal audits Prepare and revise SOPs, method statements, risk assessments etc.  Why Us?  GSK is a global biopharma company with a special purpose â€“ to unite science, technology and talent to get ahead of disease together â€“ so we can positively impact the health of billions of people and deliver stronger, more sustainable shareholder returns â€“ as an organization where people can thrive. Getting ahead means preventing disease as well as treating it, and we aim to positively impact the health of 2.5 billion people by the end of 2030.   Our success absolutely depends on our people. While getting ahead of disease together is about our ambition for patients and shareholders, itâ€™s also about making GSK a place where people can thrive. We want GSK to be a workplace where everyone can feel a sense of belonging and thrive as set out in our Equal and Inclusive Treatment of Employees policy. Weâ€™re committed to being more proactive at all levels so that our workforce reflects the communities we work and hire in, and our GSK leadership reflects our GSK workforce.   Contact information:  You may apply for this position online by selecting the Apply now button.   Important notice to Employment businesses/ Agencies  GSK does not accept referrals from employment businesses and/or employment agencies in respect of the vacancies posted on this site. All employment businesses/agencies are required to contact GSK's commercial and general procurement/human resources department to obtain prior written authorization before referring any candidates to GSK. The obtaining of prior written authorization is a condition precedent to any agreement (verbal or written) between the employment business/ agency and GSK. In the absence of such written authorization being obtained any actions undertaken by the employment business/agency shall be deemed to have been performed without the consent or contractual agreement of GSK. GSK shall therefore not be liable for any fees arising from such actions or any fees arising from any referrals by employment businesses/agencies in respect of the vacancies posted on this site. 	Full-time	23/03/2023	Karachi	Physical	Full-time	All	1-2 Year	EHS Management, Occupational Safety, Environmental Compliance, Risk Assessment",
            "Urgent Hiring: Computer Teacher - Subject Specialist for Intermediate	NCR-CET College	NCR-CET College, a renowned educational institution committed to providing quality education, is seeking a highly qualified and experienced Computer Subject Teacher to join our esteemed faculty team. Qualifications: Responsibilities: Join our esteemed institution and contribute to the development of students' computer literacy and technical skills. Together, let us empower the next generation of computer scientists, programmers, and designers. Note: Only shortlisted candidates will be contacted. Job Type: Full-time Pay: Rs50,000.00 - Rs55,000.00 per month Ability to commute/relocate: Education: Experience: Application Deadline: 31/07/2023 	Rs 50,000 - Rs 55,000 a month	31/07/2023	Karachi	Physical	Full-time	All	0-1 Year	Computer Science Education, Technical Skills, Computer Literacy, Programming Instruction, Faculty Development",
            "Data Analytics Specialist	CO/LAB PK	Company Overview: We are seeking a highly skilled Data Analytics Specialist to join our team. As a leader in our industry, we value data-driven decision-making and seek an expert in Google Analytics (GA), Google Tag Manager (GTM), Looker Studio, and other relevant analytics tools to drive insightful business strategies. Role and Responsibilities: The Data Analytics Specialist will play a pivotal role in extracting actionable insights from data, enabling our organization to make informed decisions and optimize performance across various departments. You will collaborate with cross-functional teams to gather requirements, design data-tracking strategies, and deliver clear and comprehensive reports. Your responsibilities will include: Google Analytics (GA): Google Tag Manager (GTM): Looker Studio: Data Analysis and Strategy: Qualifications: Experience: SQL: 2 years (Preferred)GTM: 2 years (Preferred)Google Analytics: 2 years (Preferred)Data Analysis: 2 years (Preferred) Job Type: Full-time Salary: Up to Rs80,000.00 per month 	Rs 80,000 a month	15/05/2023	Karachi	Physical	Full-time	All	2-3 Year	Data Analytics, Google Analytics, Google Tag Manager, Looker Studio, Data-Driven Decision Making",
            "IT Specialist	DGTX Pvt. Ltd.	About Us: DgTx Private Limited is a DgTx - Empowering Digital Taxation. We are currently seeking a skilled and experienced IT Specialist to join our team and contribute to the efficiency and security of our IT infrastructure. Job Summary: As an IT Specialist, you will play a vital role in maintaining and optimizing our network, VOIP systems, and VPN solutions. Your expertise will ensure that our technology operates seamlessly, allowing our organization to meet its business objectives. Responsibilities: Qualifications: Location Karachi Day Shift Full time position Share your CV at your earliest. Job Type: Full-time Salary: Rs60,000.00 - Rs70,000.00 per month Ability to commute/relocate: Application Question(s): Experience: 	Rs 60,000 - Rs 70,000 a month	06/05/2022	Karachi	Physical	Full-time	All	0-1 Year	IT Specialist, Network Optimization, VOIP Systems, VPN Solutions, IT Infrastructure Security",
            "OQ Officer	GSK	 Job Purpose  To ensure in-process monitoring of production and production related activities and to ensure Quality Assurance processes are implemented and used in Production Operations and Quality Operations to support producing products with respect to GSK and Regulatory specifications and bring improvement to make the processes more robust.   Education, Experience & Skills:  B-Pharm/ Pharm-D or M.Sc.  At least 2 years of relevant experience  Proficient in MS Office  Good communication and presentation skills   Key responsibilities  In-Process Control:  Ensure in-process checking during operations (oversight) are according to SOPs, understanding of core Operational Quality processes and taking action to mitigate risk.  Ensure that manufacturing, filling and packing activities are performed according to BMR, BPR and relevant SOPs.  Data Integrity & Compliance: Support in Data integrity implementation and improve the DI controls at site.  Product Release: Support in compilation and review batch documents and release products to ensure that manufacturing, filling, and packaging activities are performed according to BMRs, BPRs and relevant SOPs and ensure that batch dossiers are retained as per local regulatory and GSK record retention policy, if required.  Site Archive Room, Batch Document Room & Retained Sample Room: Ensure that compliance related documents are retained as per GSK record retention policy and ensure that batch record & retained samples are stored, archived and traceability of the documents and retained samples are managed.  Deviation Handling: Report deviation and support in rectification of deviations from cGMP or the Quality Management System, providing advice to line management to ensure that cGMP compliance requirements are built into the site's core practices and ensure that product quality issues are correctly investigated, and that appropriate corrective and preventive actions are implemented.  Investigation Handling: Support in investigations of products failing to meet standards, support and coordinate with stake holders for the CAPA preparation.  CAPA Plan Handling: Ensure all QMS requirements for Operational Quality including Self- Inspections, SOP status, Trainings, CAPA closure, Gap analysis actions and others are timely completed and communicated to relevant stake holders.  Validations:  Execution of Validation Protocols and activities on floor.  Support in site validation activities by providing OQ input.  Environment, Health & Safety:  To ensure that EHS practices are being maintained.  Implement and follow EHS standards  Work With Zero Accident, Defects & Waste by Committing To Safety Fundamentals:  To ensure that EHS practices are being maintained.  Reporting of ZIP, ZAP & ZWP and their timely closures to meet site target.  Actively participate in safety and health related events and improve the working conditions in order to maintain a safer and healthier environment.  Why Us?  GSK is a global biopharma company with a special purpose â€“ to unite science, technology and talent to get ahead of disease together â€“ so we can positively impact the health of billions of people and deliver stronger, more sustainable shareholder returns â€“ as an organization where people can thrive. Getting ahead means preventing disease as well as treating it, and we aim to positively impact the health of 2.5 billion people by the end of 2030.   Our success absolutely depends on our people. While getting ahead of disease together is about our ambition for patients and shareholders, itâ€™s also about making GSK a place where people can thrive. We want GSK to be a workplace where everyone can feel a sense of belonging and thrive as set out in our Equal and Inclusive Treatment of Employees policy. Weâ€™re committed to being more proactive at all levels so that our workforce reflects the communities we work and hire in, and our GSK leadership reflects our GSK workforce.   Contact information:  You may apply for this position online by selecting the Apply now button.   Important notice to Employment businesses/ Agencies  GSK does not accept referrals from employment businesses and/or employment agencies in respect of the vacancies posted on this site. All employment businesses/agencies are required to contact GSK's commercial and general procurement/human resources department to obtain prior written authorization before referring any candidates to GSK. The obtaining of prior written authorization is a condition precedent to any agreement (verbal or written) between the employment business/ agency and GSK. In the absence of such written authorization being obtained any actions undertaken by the employment business/agency shall be deemed to have been performed without the consent or contractual agreement of GSK. GSK shall therefore not be liable for any fees arising from such actions or any fees arising from any referrals by employment businesses/agencies in respect of the vacancies posted on this site. 	Unknown	05/06/2023	Karachi	Physical	Full-time	Female	0-1 Year	Quality Assurance, In-Process Monitoring, Data Integrity, Deviation Handling, Validation Protocols",
            "Data Analyst Manager	Mac Care	Data Anaylst ManagerMIS & Business Intelligence Developer Position Summary: This person will be the expert in organizing data and transforming it into compelling storytelling and must have worked with international clients, especially in the US Healthcare industry. This person must be a critical thinker and self-starter that can push important initiatives that help the company grow and expand. Should be able to work during US operating hours and can bear the workload pressure while working directly with the top tier in the US. Must be able to receive requirements from the business team and can translate them into a plan and with companywide reports/dashboards accordingly. KEY RESPONSIBILITIES OF THIS JOB: Â· Develop and implement strategies and policies that support the organization's goals and objectives for information systems and business intelligence. Â· Develop and Manage CEOâ€™s Dashboard Â· Management, development and maintenance of dashboards, databases, data warehouses, and other information systems. Â· Develop and maintain data models and schemes and ensure the accuracy and integrity. Â· Develop end-to-end RCM reports and other financial analysis for the US healthcare industry. Â· Database management (data analytics and data modeling) Â· Analytics related to working with structured datasets. Â· Schedule and produce periodic reports regarding companywide performance, keeping the 360-degree coverage factor in mind. Â· Analyzing existing operations, protocols, and reporting processes of all the departments and making plans for improvement Â· Analyze business information to identify process improvements for increasing business efficiency and effectiveness. Â· Developing and executing queries, creating reports, dashboards, and data visualizations to both analyze the results of the analysis and to make it accessible to decision-makers. Â· Designing, developing, and maintaining business intelligence solutions Â· Manage and educate the team members to help them with usage and navigation using the reporting tools and using the right reports/metrics. Â· Designing and development of Power BI Report Server Â· Coding for Microsoft Excel, Microsoft Power BI, or any other tool. Required Skills/Abilities: Â· Bachelor's degree in computer science, information systems, or MSc in Statistics, Applied Mathematics, or a related field. Â· 3+ years of experience in information systems management, data analysis Â· Strong analytical skills, with the ability to analyze complex data sets and identify trends and patterns. Â· Strong project management skills Â· Experience with business intelligence tools, such as Power BI or Tableau. Â· Familiarity with data security policies and procedures. Â· Grip on Power BI, Microsoft Excel, Dashboard, and Data visualization Â· Experience in working with US clients is a plus. Â· Experience in the US Healthcare industry is a plus. Â· High-level data visualization skills Â· Knowledge of HIPAA compliance a plus Â· Excellent Interpersonal skills Â· Must have good written and verbal communication skills. Benefit: 5 days job, Market Competitive Salary, Provident fund, Medical Insurance (self) and EOBI Job Type: Full-time Timing: 8am â€“ 5pm CST Job Type: Full-time Salary: Rs1,150.00 per month Experience: Shift availability: 	Rs 115,000 a month	02/05/2022	Karachi	Hybrid	Full-time	All	1-2 Year	Data Analyst, Business Intelligence Developer, Data Modeling, Power BI, US Healthcare Industry"
            ]

correct_answers = [
  ["Data Scientist",	"Herbion Private Limited",	"Job Summary: Seeking a skilled and motivated Data Scientist to join the Supply Chain Planning Department. Responsible for analyzing large datasets, developing predictive models, and optimizing supply chain processes. Collaborate with cross-functional teams to improve demand forecasting, inventory management, and overall supply chain efficiency. Strong data analysis, statistical modeling, and machine learning skills required. Job Type: Full-time Salary: Rs60,000.00 - Rs80,000.00 per month Ability to commute/relocate: Application Deadline: 30/06/2023", "Rs 60,000 - Rs 80,000 a month",	"30/06/2023",	"Karachi",	"Physical",	"Full-time",	"All",	"Unknown"],
  ["Freelance Information Technology. (Part Time)",	"Men's Wear Brand" ,	"WEâ€™RE HIRING Freelance Information Technology. (Part Time) As an IT professional you are generally involves managing and storing data using computers, software, databases, networks, and servers. you may write programs, maintain networks, analyze systems, and provide technical support. Requirements: Education: Bachelorâ€™s Degree or equivalent experience in Computer Science, Information Technology, related field. Experience: 3-5 Years IT End User Support / Helpdesk experience Location: Korangi Industrial Area Karachi. Email: goodjobs2022@gmail.com Job Type: Part-timePart-time hours: 24 per week Salary: Rs30,000.00 - Rs35,000.00 per month Ability to Commute: Ability to Relocate: ","Rs 30,000 - Rs 35,000 a month", "22/02/2023" ,"Karachi", "Physical" ,"Part-time"	,"All"	,"3-5 Year"],
  ["Data Analyst", "The Dynamics Research Consultants","Key Responsibilities: Qualification Job Type: Full-time Salary: Rs50,000.00 - Rs80,000.00 per month Experience:","Rs 50,000 - Rs 80,000 a month",	"23/03/2022"	,"Karachi"	,"Physical"	,"Full-time"	,"All"	,"1 Year"],
  ["IT Support",	"GENOZONE INTERNATIONAL",	"looking for Male IT IT Duties and Responsibilities Requirements Timing 6:PM to 3:AM evening Job Types: Part-time, Full-time Salary: Rs25,000.00 - Rs30,000.00 per month Ability to commute/relocate:", 	"Rs 25,000 - Rs 30,000 a month",	"25/04/2019","Karachi","Physical",	"Full-time"	,"All",	"0-1 Year"],
  ["Operation/Data Analyst"	,"Pixel Media & Production House","Job Location: Brookes Chowrangi (Godaam Chowrangi), Korangi Industrial Area Job Type: On-Site Salary : 40k to 45k Job Description: We are looking for a strong candidate that forms a key part of our Data team, enabling us in achieving the business goals. The candidate can also carry out all tasks related to Data & Business Intelligence & ML. Operations Analyst will be responsible for analyzing and interpreting large amounts of data. You will commonly work with a variety of different types of data, including customer care, sales, Operations, supply chain etc. Job Responsibilities: A Operations Analyst typically has a wide range of responsibilities, which can include: Requirement: What you get in return: As a team member, youâ€™ll work in a fast-paced corporate environment and make an impact on our business, contributing to the success of our company. Through on-the-job training and learning opportunities, you will develop valuable skills for the future. Job Type: Full-time Salary: Rs40,000.00 - Rs45,000.00 per month Ability to commute/relocate: Application Question(s): Education:", "Rs 40,000 - Rs 45,000 a month"	, "22/01/2022"	, "Karachi"	, "Physical"	, "Full-time"	, "All"	, "1-2 Year"],
  ["Data Analyst","Garments company","We are seeking a talented â€œData Analystâ€ to join Apparel Brand to drive analyzing, reporting, and growth. The ideal candidate will be passionate about the Brands Industry. Responsibilities: Analytical/Data Skills: Qualifications: Gender: Male (Preferred) Location: I.I Chundrigar Road Karachi. Salary: Rs. 75K to 125K Interested candidates may send their resumes to hrgoodjob2023@gmail.com Only shortlisted candidate will be called for interview Job Type: Full-time Salary: Rs75,000.00 - Rs125,000.00 per month Ability to Commute: Ability to Relocate:","Rs 75,000 - Rs 125,000 a month","25/03/2023","Karachi","Physical","Full-time","Male","2 Years"],
  ["Data Engineer"	,"Dolphin Analytics"	,"Job description Requirements Technical expertise in data models, database design development, and data miningCreating integrated data pipelines and APIsExperience building reporting/data visualizationsSolid knowledge of SQL and Data WarehousingExperience in Python Scraping Qualifications 1 year to 3 years experience in a Data Science roleBachelor in Computer Science/ Computer Engineering or MathematicsExcellent verbal and written communication skills (Toastmasters will be given preference) Job Types: Full-time, ContractContract length: 12 months Salary: Rs50,000.00 - Rs130,000.00 per month Ability to commute/relocate: Education:" 	,"Rs 50,000 - Rs 130,000 a month"	,"27/04/2021"	,"Karachi"	,"Physical"	,"Full-time"	,"All"	,"1-3 Year"],
  ["Data Analyst"	,"Cooperative Computing"	,"Cooperative Computing (CC):â€¯ We accelerate growth minded companies into the automated economy. The business market is in rapid change, with consumer behavior placing significantly high expectations on businesses at every phase in the client experience.â€¯ Each day, we experience a company dramatically shifting â€œindustry normsâ€ and in many cases, removing historical market leaders from their market leading position.â€¯ These elements create extraordinary opportunities for our team members to excel. CC delivers superior client experiences as the premier digital enabler of growth minded enterprises enabling their rapid growth and ensuring their sustainable and smooth transition into the Automated Economy. Our team is passionate in delivering client value and is fanatical in how we go about ensuring we deliver extraordinary business results for our clients.â€¯ We are committed to growing as individuals first, becoming the best version of ourselves in who we have been created to be.â€¯ We take responsibility in our thoughts and actions, know our purpose and our end in mind and put these first in our lives. The Role: To advance our mission of inspiring greatness and transforming the lives of others, our Data Analyst will play a key role in collecting, analyzing, and interpreting data to provide valuable insights that drive informed business decisions. Your responsibilities will include data collection, cleaning, analysis, visualization, and reporting. You will work with various data sources, tools, and databases to ensure accurate and reliable data. Your ability to identify patterns, create visualizations, and effectively communicate findings to stakeholders will contribute to data-driven decision-making within the organization. Capabilities (Key Behaviors): The Data Analyst is expected to have: Results: By leveraging these capabilities, the Data Analyst will aim to achieve: Job Type: Full-time Experience: Application Deadline: 29/09/2023 	","Unknown"	,"29/09/2023"	,"Karachi"	,"Physical"	,"Full-time"	,"All"	,"0-1 Year"],
  ["BI Analyst",	"HubDigit Pvt Ltd",	"As a Business Intelligence Analyst, you will play a pivotal role in translating data into actionable insights that drive strategic decisions. Leveraging your analytical skills and business acumen, you'll collaborate with cross-functional teams to deliver valuable data-driven solutions. Responsibilities: - Gather and analyze business requirements to develop data-driven insights. - Design and create interactive dashboards and reports for various stakeholders. - Identify trends, patterns, and opportunities within complex datasets. - Collaborate with data engineers to ensure seamless data integration and quality. - Present findings and recommendations to both technical and non-technical audiences. - Monitor key performance indicators and provide proactive insights. - Participate in the design and development of data models and ETL processes. - Stay updated on industry best practices and emerging trends in BI and analytics. Qualifications: - Bachelor's degree in Business, Computer Science, Analytics, or a related field. - Proven experience as a Business Intelligence Analyst or similar role. - Strong proficiency in data visualization tools such as Tableau, Power BI, or similar. - Proficiency in SQL for data manipulation and extraction. - Analytical mindset with the ability to translate data into actionable insights. - Excellent communication skills to convey complex findings clearly. - Familiarity with data warehousing concepts and ETL processes. - Detail-oriented and able to work both independently and collaboratively. - Knowledge of programming languages (Python, R) is a plus. - Prior experience with cloud platforms and big data technologies is advantageous. Job Type: Full-time Salary: From Rs100,000.00 per month", 	"Rs 100,000 a month",	"15/04/2023"	,"Karachi",	"Physical",	"Full-time",	"All",	"0-1 Year"],
  ["IT Support Executive"	,"Lime Software Logics (SMC-PVT) Limited"	,"Responsible for the maintenance, configuration, and reliable operation of the organization's computer systems and network infrastructure. This role involves providing technical support to end-users, troubleshooting hardware and software issues, and ensuring the smooth functioning of the IT environment. The IT/Network Officer also assists in the implementation of IT projects and security measures to safeguard the organization's data and systems. Tasks: Qualifications and Requirements: Job Type: Full-time Salary: Rs45,000.00 - Rs55,000.00 per month Ability to commute/relocate: Experience: Shift availability: 	","Rs 45,000 - Rs 55,000 a month"	,"25/03/2023"	,"Karachi"	,"Physical"	,"Full-time"	,"All"	,"2-3 Year"],
  ["Secretary/Personal Assistant",	"M.S.Ajmal Business Consultant",	"Personal Assistant with excellent computing background to Director who is a multiple business owner in the UK and UAE. The sectors of the business range from IT Software development to construction, property development and investments. The successful candidate for this position will have experience handling high-level tasks, an ability to maintain confidentiality, an affinity for multi-tasking, and a professional work ethic. Additionally, the Personal Assistant will have to be well organised and have very strong communication skills in English Language (Spoken and Written). Key skills and experience required: Key responsibilities; Salary to be negotiated subject to applicants experience. Please get in touch with CV, cover letter and availability for interview. Job Type: Full-time Salary: Minimum 60,000.00 PKR per month with Bonus scheme Schedule: Supplemental pay types: Work Location: This is a work from home position (Remote) Job Type: Full-time Salary: From Rs60,000.00 per month", 	"Rs 60,000 a month",	"27/01/2023",	"Karachi",	"Remote",	"Full-time",	"All",	"1-2 Year"],
  ["Data Entry Executive"	,"Aykays"	,"Aykays is looking for a fresh candidates preferably with a computer science background to work on our in-house projects that require good English writing skills as well as speed and enthusiasm. We need someone who is:CreativeRegularPunctualProficient in EnglishSelf-motivated with strong work ethics. Fresh grads are also encouraged to apply for internships. The internships will be paid with a stipend of PKR 20000 + up to 15,000 and more commission per month. Timings: 3pm to 12am OR 10pm to 7am Job Types: Full-time, Part-time, Internship, Contract, CommissionContract length: 3 monthsPart-time hours: 36 per week Salary: Rs20,000.00 per month Ability to commute/relocate:" 	,"Rs 20,000 a month"	,"25/05/2023"	,"Karachi"	,"Physical"	,"Full-time"	,"All"	,"0-1 Year"],
  ["Production Support Officer"	,"GSK"	 ,"Job Purpose  To work on Tablet Blister/Tablet Packaging area ensuring the required output and complying with applicable GMP, EHS and Regulatory standards.   Education, Experience & Skills:  Diploma/ BTech  Minimum 2-3 years in relevant role  QMS & EHS training   Key responsibilities:  Ensure Safety of the area with Zero Waste Promotions and ZAP & ZIP reporting.  Keep up-to-date production, downtime, changeover, preventive maintenance, and other records on daily basis for Tablet Blister/Tablet packaging.  Hands on experience in Tablet, blister and cartoning operation.  Able to troubleshoot and rectify the breakdown on Tablet Blister and Cartoning Machine.  Expert in product changeover of different format at blister and cartoning machine.  Suggest and implement measures to improve the machine efficiency OEE.  Ensure all production floorâ€™s KPI are being maintained and met. e.g., Adherence to Daily OEE target and Adherence to conformance of daily plan.  Ensure the GMP (proper labelling, IPC etc.) and EHS (Zero access, LOTO etc.) compliance during operation.  Ensure cost efficient way, right first-time operation, minimizing changeovers and avoiding wastages.  Maintain complete record of the respective machine e.g., daily working Logbooks, Maintenance Record, Cleaning and Changeover Record etc.  Ensure Data integrity compliance and improve the DI control (ALCOA principle) at Packaging.  Ensure all Blister/Tablet packaging operation related End to End production SAP transactions are punched timely.  Why Us?  GSK is a global biopharma company with a special purpose â€“ to unite science, technology and talent to get ahead of disease together â€“ so we can positively impact the health of billions of people and deliver stronger, more sustainable shareholder returns â€“ as an organization where people can thrive. Getting ahead means preventing disease as well as treating it, and we aim to positively impact the health of 2.5 billion people by the end of 2030.   Our success absolutely depends on our people. While getting ahead of disease together is about our ambition for patients and shareholders, itâ€™s also about making GSK a place where people can thrive. We want GSK to be a workplace where everyone can feel a sense of belonging and thrive as set out in our Equal and Inclusive Treatment of Employees policy. Weâ€™re committed to being more proactive at all levels so that our workforce reflects the communities we work and hire in, and our GSK leadership reflects our GSK workforce.   Contact information:  You may apply for this position online by selecting the Apply now button.   Important notice to Employment businesses/ Agencies  GSK does not accept referrals from employment businesses and/or employment agencies in respect of the vacancies posted on this site. All employment businesses/agencies are required to contact GSK's commercial and general procurement/human resources department to obtain prior written authorization before referring any candidates to GSK. The obtaining of prior written authorization is a condition precedent to any agreement (verbal or written) between the employment business/ agency and GSK. In the absence of such written authorization being obtained any actions undertaken by the employment business/agency shall be deemed to have been performed without the consent or contractual agreement of GSK. GSK shall therefore not be liable for any fees arising from such actions or any fees arising from any referrals by employment businesses/agencies in respect of the vacancies posted on this site." 	,"Unknown"	,"02/03/2023"	,"Karachi"	,"Physical"	,"Full-time"	,"All"	,"0-1 Year"],
  ["Data Analyst (CRM)"	,"Domino's Pizza Pakistan"	,"Location: You will work in our Karachi office for an organization based in Saudi Arabia (KSA). Job Title â€“ Data Analytics Specialist (CRM) Objective â€“ The objective of the data analytics specialist role is to develop and implement customer segmentations, campaign analysis framework, run customer behavioral analysis and derive insights that would help to drive business decisions. The role involves leveraging data analysis and visualization tools to extract actionable insights, optimize processes and drive informed decision making within the organization. Responsibilities: Requirements: Job Type: Full-time Education: Experience: Application Deadline: 30/09/2023" 	,"Unknown"	,"30/09/2023"	,"Karachi"	,"Physical"	,"Full-time"	,"All"	,"2-3 Year"],
  ["Project Trainee"	,"GSK"	 ,"Job Purpose  Implement EHS programs based on EHS management system in order to achieve the GSK Strategic Deployment Objectives in consideration of EHS policy and vision.   Education, Experience & Skills:  B.E (Engineering)/ Masters (Environmental Sciences)  EHS Certification  At least 1 year experience with managing EHS and different domains related to Health and Safety in an organization  Must possess knowledge of industry standards and codes related to occupational safety and design  Good communication and presentation skills   Key responsibilities:  Ensure compliance to local industry and government regulations, GSK standards, procedures, guidelines at the site and ensure continuous EHS improvement in all work processes.  Ensure compliance of the releases to environment from the facility's operations; in accordance with applicable regulatory limits and other relevant environmental discharge criteria. Compilation and data analysis.  Implement controls related to Process safety, permit to work and contractor management at site.  Carry out EHS related trainings for down the line staff based on their training needs.  Conduct and assist departments in carrying out risk assessments and L-1 audits.  Assist the EHS Manager and Site for implementation of safety initiatives and monitor progress against them at the site  Participate in different meetings and forums and provide useful inputs regarding existing EHS issues, and requirements, to achieve the corporate EHS goals.  Conduct EHS internal audits Prepare and revise SOPs, method statements, risk assessments etc.  Why Us?  GSK is a global biopharma company with a special purpose â€“ to unite science, technology and talent to get ahead of disease together â€“ so we can positively impact the health of billions of people and deliver stronger, more sustainable shareholder returns as an organization where people can thrive. Getting ahead means preventing disease as well as treating it, and we aim to positively impact the health of 2.5 billion people by the end of 2030.   Our success absolutely depends on our people. While getting ahead of disease together is about our ambition for patients and shareholders, itâ€™s also about making GSK a place where people can thrive. We want GSK to be a workplace where everyone can feel a sense of belonging and thrive as set out in our Equal and Inclusive Treatment of Employees policy. Weâ€™re committed to being more proactive at all levels so that our workforce reflects the communities we work and hire in, and our GSK leadership reflects our GSK workforce.   Contact information:  You may apply for this position online by selecting the Apply now button.   Important notice to Employment businesses/ Agencies  GSK does not accept referrals from employment businesses and/or employment agencies in respect of the vacancies posted on this site. All employment businesses/agencies are required to contact GSK's commercial and general procurement/human resources department to obtain prior written authorization before referring any candidates to GSK. The obtaining of prior written authorization is a condition precedent to any agreement (verbal or written) between the employment business/ agency and GSK. In the absence of such written authorization being obtained any actions undertaken by the employment business/agency shall be deemed to have been performed without the consent or contractual agreement of GSK. GSK shall therefore not be liable for any fees arising from such actions or any fees arising from any referrals by employment businesses/agencies in respect of the vacancies posted on this site. ",	"Unknown"	,"23/03/2023"	,"Karachi"	,"Physical"	,"Full-time"	,"All"	,"1-2 Year"],
  ["Urgent Hiring: Computer Teacher - Subject Specialist for Intermediate"	,"NCR-CET College"	,"NCR-CET College, a renowned educational institution committed to providing quality education, is seeking a highly qualified and experienced Computer Subject Teacher to join our esteemed faculty team. Qualifications: Responsibilities: Join our esteemed institution and contribute to the development of students' computer literacy and technical skills. Together, let us empower the next generation of computer scientists, programmers, and designers. Note: Only shortlisted candidates will be contacted. Job Type: Full-time Pay: Rs50,000.00 - Rs55,000.00 per month Ability to commute/relocate: Education: Experience: Application Deadline: 31/07/2023 "	,"Rs 50,000 - Rs 55,000 a month"	,"31/07/2023"	,"Karachi"	,"Physical"	,"Full-time"	,"All"	,"0-1 Year"],
  ["Data Analytics Specialist","CO/LAB PK"	,"Company Overview: We are seeking a highly skilled Data Analytics Specialist to join our team. As a leader in our industry, we value data-driven decision-making and seek an expert in Google Analytics (GA), Google Tag Manager (GTM), Looker Studio, and other relevant analytics tools to drive insightful business strategies. Role and Responsibilities: The Data Analytics Specialist will play a pivotal role in extracting actionable insights from data, enabling our organization to make informed decisions and optimize performance across various departments. You will collaborate with cross-functional teams to gather requirements, design data-tracking strategies, and deliver clear and comprehensive reports. Your responsibilities will include: Google Analytics (GA): Google Tag Manager (GTM): Looker Studio: Data Analysis and Strategy: Qualifications: Experience: SQL: 2 years (Preferred)GTM: 2 years (Preferred)Google Analytics: 2 years (Preferred)Data Analysis: 2 years (Preferred) Job Type: Full-time Salary: Up to Rs80,000.00 per month "	,"Rs 80,000 a month"	,"15/05/2023"	,"Karachi"	,"Physical"	,"Full-time"	,"All"	,"2-3 Year"],
  ["IT Specialist"	,"DGTX Pvt. Ltd"	,"About Us: DgTx Private Limited is a DgTx - Empowering Digital Taxation. We are currently seeking a skilled and experienced IT Specialist to join our team and contribute to the efficiency and security of our IT infrastructure. Job Summary: As an IT Specialist, you will play a vital role in maintaining and optimizing our network, VOIP systems, and VPN solutions. Your expertise will ensure that our technology operates seamlessly, allowing our organization to meet its business objectives. Responsibilities: Qualifications: Location Karachi Day Shift Full time position Share your CV at your earliest. Job Type: Full-time Salary: Rs60,000.00 - Rs70,000.00 per month Ability to commute/relocate: Application Question(s): Experience:" 	,"Rs 60,000 - Rs 70,000 a month"	,"06/05/2022"	,"Karachi"	,"Physical"	,"Full-time"	,"All","0-1 Year"],
  ["OQ Officer"	,"GSK" ,"Job Purpose  To ensure in-process monitoring of production and production related activities and to ensure Quality Assurance processes are implemented and used in Production Operations and Quality Operations to support producing products with respect to GSK and Regulatory specifications and bring improvement to make the processes more robust.   Education, Experience & Skills:  B-Pharm/ Pharm-D or M.Sc.  At least 2 years of relevant experience  Proficient in MS Office  Good communication and presentation skills   Key responsibilities  In-Process Control:  Ensure in-process checking during operations (oversight) are according to SOPs, understanding of core Operational Quality processes and taking action to mitigate risk.  Ensure that manufacturing, filling and packing activities are performed according to BMR, BPR and relevant SOPs.  Data Integrity & Compliance: Support in Data integrity implementation and improve the DI controls at site.  Product Release: Support in compilation and review batch documents and release products to ensure that manufacturing, filling, and packaging activities are performed according to BMRs, BPRs and relevant SOPs and ensure that batch dossiers are retained as per local regulatory and GSK record retention policy, if required.  Site Archive Room, Batch Document Room & Retained Sample Room: Ensure that compliance related documents are retained as per GSK record retention policy and ensure that batch record & retained samples are stored, archived and traceability of the documents and retained samples are managed.  Deviation Handling: Report deviation and support in rectification of deviations from cGMP or the Quality Management System, providing advice to line management to ensure that cGMP compliance requirements are built into the site's core practices and ensure that product quality issues are correctly investigated, and that appropriate corrective and preventive actions are implemented.  Investigation Handling: Support in investigations of products failing to meet standards, support and coordinate with stake holders for the CAPA preparation.  CAPA Plan Handling: Ensure all QMS requirements for Operational Quality including Self- Inspections, SOP status, Trainings, CAPA closure, Gap analysis actions and others are timely completed and communicated to relevant stake holders.  Validations:  Execution of Validation Protocols and activities on floor.  Support in site validation activities by providing OQ input.  Environment, Health & Safety:  To ensure that EHS practices are being maintained.  Implement and follow EHS standards  Work With Zero Accident, Defects & Waste by Committing To Safety Fundamentals:  To ensure that EHS practices are being maintained.  Reporting of ZIP, ZAP & ZWP and their timely closures to meet site target.  Actively participate in safety and health related events and improve the working conditions in order to maintain a safer and healthier environment.  Why Us?  GSK is a global biopharma company with a special purpose â€“ to unite science, technology and talent to get ahead of disease together â€“ so we can positively impact the health of billions of people and deliver stronger, more sustainable shareholder returns â€“ as an organization where people can thrive. Getting ahead means preventing disease as well as treating it, and we aim to positively impact the health of 2.5 billion people by the end of 2030.   Our success absolutely depends on our people. While getting ahead of disease together is about our ambition for patients and shareholders, itâ€™s also about making GSK a place where people can thrive. We want GSK to be a workplace where everyone can feel a sense of belonging and thrive as set out in our Equal and Inclusive Treatment of Employees policy. Weâ€™re committed to being more proactive at all levels so that our workforce reflects the communities we work and hire in, and our GSK leadership reflects our GSK workforce.   Contact information:  You may apply for this position online by selecting the Apply now button.   Important notice to Employment businesses/ Agencies  GSK does not accept referrals from employment businesses and/or employment agencies in respect of the vacancies posted on this site. All employment businesses/agencies are required to contact GSK's commercial and general procurement/human resources department to obtain prior written authorization before referring any candidates to GSK. The obtaining of prior written authorization is a condition precedent to any agreement (verbal or written) between the employment business/ agency and GSK. In the absence of such written authorization being obtained any actions undertaken by the employment business/agency shall be deemed to have been performed without the consent or contractual agreement of GSK. GSK shall therefore not be liable for any fees arising from such actions or any fees arising from any referrals by employment businesses/agencies in respect of the vacancies posted on this site. "	,"Unknown"	,"05/06/2023"	,"Karachi"	,"Physical"	,"Full-time"	,"Female"	,"0-1 Year"],
  ["Data Analyst Manager"	,"Mac Care"	,"Data Anaylst ManagerMIS & Business Intelligence Developer Position Summary: This person will be the expert in organizing data and transforming it into compelling storytelling and must have worked with international clients, especially in the US Healthcare industry. This person must be a critical thinker and self-starter that can push important initiatives that help the company grow and expand. Should be able to work during US operating hours and can bear the workload pressure while working directly with the top tier in the US. Must be able to receive requirements from the business team and can translate them into a plan and with companywide reports/dashboards accordingly. KEY RESPONSIBILITIES OF THIS JOB: Â· Develop and implement strategies and policies that support the organization's goals and objectives for information systems and business intelligence. Â· Develop and Manage CEOâ€™s Dashboard Â· Management, development and maintenance of dashboards, databases, data warehouses, and other information systems. Â· Develop and maintain data models and schemes and ensure the accuracy and integrity. Â· Develop end-to-end RCM reports and other financial analysis for the US healthcare industry. Â· Database management (data analytics and data modeling) Â· Analytics related to working with structured datasets. Â· Schedule and produce periodic reports regarding companywide performance, keeping the 360-degree coverage factor in mind. Â· Analyzing existing operations, protocols, and reporting processes of all the departments and making plans for improvement Â· Analyze business information to identify process improvements for increasing business efficiency and effectiveness. Â· Developing and executing queries, creating reports, dashboards, and data visualizations to both analyze the results of the analysis and to make it accessible to decision-makers. Â· Designing, developing, and maintaining business intelligence solutions Â· Manage and educate the team members to help them with usage and navigation using the reporting tools and using the right reports/metrics. Â· Designing and development of Power BI Report Server Â· Coding for Microsoft Excel, Microsoft Power BI, or any other tool. Required Skills/Abilities: Â· Bachelor's degree in computer science, information systems, or MSc in Statistics, Applied Mathematics, or a related field. Â· 3+ years of experience in information systems management, data analysis Â· Strong analytical skills, with the ability to analyze complex data sets and identify trends and patterns. Â· Strong project management skills Â· Experience with business intelligence tools, such as Power BI or Tableau. Â· Familiarity with data security policies and procedures. Â· Grip on Power BI, Microsoft Excel, Dashboard, and Data visualization Â· Experience in working with US clients is a plus. Â· Experience in the US Healthcare industry is a plus. Â· High-level data visualization skills Â· Knowledge of HIPAA compliance a plus Â· Excellent Interpersonal skills Â· Must have good written and verbal communication skills. Benefit: 5 days job, Market Competitive Salary, Provident fund, Medical Insurance (self) and EOBI Job Type: Full-time Timing: 8am â€“ 5pm CST Job Type: Full-time Salary: Rs1,150.00 per month Experience: Shift availability: "	,"Rs 115,000 a month"	,"02/05/2022"	,"Karachi"	,"Hybrid"	,"Full-time"	,"All"	,"1-2 Year"],
]

# %% [markdown]
# ## Questions to feed the Model
# TODO questions catering to a list as one field

# %%
questions = ["What is the job title?",
             "What is the company name?",
             "",
             "What is the job salary?",
             "What is the job deadline?",
             "What city is the job in?",
             "Is the job mode physical , online, hybrid?",
             "Is the job type full time, part time or contractual?",
             "Is the job for males, females or both?",
             "Years of experience required?",
             "What is the email mentioned in this job description?",
             "What is the phone number mentioned in this job description?"
            ]

questions2 = ["What is the title of the job position being advertised?",
              "Which company is offering the job? The full name of the company is required.",
              "",
              "What is the salary range or amount stated for the job?",
              "What is the application deadline for the job?",
              "Where is the job location or what is the job city mentioned in the description?",
              "Is the job described as on-site, remote, or hybrid?",
              "Is the job full-time, part-time, or contractual as mentioned in the description?",
              "Does the job specify a preferred gender, if any?",
              "How many years of experience are required for the job?",
              "What is the email mentioned in this job description?",
              "What is the phone number mentioned in this job description?"
            ]

# %% [markdown]
# ## Question Mapping Dictionary

# %%
field_dict = {  0: "job_title",
                1: "company_name",
                2: "description",
                3: "salary",
                4: "deadline",
                5: "location",
                6: "mode",
                7: "type",
                8: "sex",
                9: "experience",
                10: "email",
                11: "phone"
            }

# %% [markdown]
# ## Preprocessing
# TODO Add more stuff

# %%
def clean_text(text):
    # Fix encoding issues, such as 'â€™' turning into proper apostrophes
    text = text.encode('latin1').decode('utf8').encode('ascii', 'ignore').decode('ascii')
    # Replace multiple whitespace with a single space
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# %% [markdown]
# ## Postprocessing
# TODO:
# - Job Title:
# - Company Name:
# - Salary:
# - Experience (if possible):

# %%
def validate_and_format_answer(answer, field_type):
    lower_answer = answer.lower()
    
    if field_type == 'job_title':
        pass
    
    elif field_type == 'company_name':
        pass

    elif field_type == 'description':
        pass

    elif field_type == 'salary':
        if '000' in lower_answer:
            answer = answer
        else:
            pattern1 = r'\b(?:\d{1,3}(,\d{3})*){1}(?:,?\d*)\s?-\s?(?:\d{1,3}(,\d{3})*){1}(?:,?\d*)000\b'
            pattern2 = r'\b\d{1,3}(,\d{3})*,?\d*000\b'
            pattern3 = r'(\b\d{4,}(?=[a-zA-Z])|\b\d{5,}\b)'

            match1 = re.search(pattern1, answer)
            match2 = re.search(pattern2, answer)
            match3 = re.search(pattern3, answer)

            if match1:
                print(match1.group(0))
                answer = match1.group() 
            elif match2:
                print(match2.group(0))
                answer = match2.group()
            elif match3:
                print(match3.group(0))
                answer = match3.group()
            else :
                answer = None

    elif field_type == 'deadline':
        temp = answer
        # Check for dates in the format dd/mm/yyyy
        matches = re.search(r'\b\d{1,2}/\d{1,2}/\d{4}\b', temp)
        answer = matches.group() if matches else None
        
        # If no match found in the first format, check for written dates
        if not answer:
            # Check for dates like "24th February 2024," "15 Dec," "Thirteen Jan," and "Twelve March 2024"
            written_date_matches = re.search(r'(\d{1,2}(?:st|nd|rd|th)?\s*(?:January|February|March|April|May|June|July|August|September|October|November|December|Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)(?:\s*(?:\d{4}|\d{2}))?)', temp, re.IGNORECASE)
            answer = written_date_matches.group(1) if written_date_matches else None
    
    elif field_type == 'location':
        if 'karachi' in lower_answer:
            answer = "Karachi"
        elif 'lahore' in lower_answer:
            answer = "Lahore"
        elif 'islamabad' in lower_answer:
            answer = "Islamabad"
        elif 'rawalpindi' in lower_answer:
            answer = "Rawalpindi"
        elif 'peshawar' in lower_answer:
            answer = "Peshawar"
        elif 'quetta' in lower_answer:
            answer = "Quetta"
        elif 'multan' in lower_answer:
            answer = "Multan"
        elif 'hyderabad' in lower_answer:
            answer = "Hyderabad"
        else:
            answer = ""
        
    elif field_type == 'mode':
        if 'hybrid' in lower_answer or (('onsite' in lower_answer or 'on-site' in lower_answer or 'physical' in lower_answer) and ('online' in lower_answer or 'remote' in lower_answer or 'work from home' in lower_answer)):
            answer = "Hybrid"
        elif 'onsite' in lower_answer or 'on-site' in lower_answer or 'physical' in lower_answer:
            answer = 'Physical'
        elif 'online' in lower_answer or 'remote' in lower_answer or 'work from home' in lower_answer:
            answer = "Remote"
        else:
            answer = None
    
    elif field_type == 'type':
        if 'fulltime' or 'full-time' or 'full time' in lower_answer: 
            answer ="Full-time"
        elif 'parttime' or 'part-time' or 'part time' in lower_answer: 
            answer = "Part-time"
        elif 'internship' in lower_answer: 
            answer = "Internship"
        elif 'contract' or "contractual" in lower_answer: 
            answer = "Contractual"
        elif 'volunteer' or 'social work' in lower_answer:
            answer ='Social Work'
        else:
            answer = None

    elif field_type == 'sex':
        if "" or "unknown" or ('male' and 'female') in lower_answer:
            answer = "No Preference"
        elif "male" in lower_answer:
            answer = "Male"
        elif "female" in lower_answer:
            answer = "Female"
        elif 'intersex' or 'inter-sex' in lower_answer:
            answer = "Intersex"
        else:
            answer = None

    elif field_type == 'experience':
        matches = re.search(r'\b\d+\s+years\b', answer, re.IGNORECASE)
        answer = matches.group() if matches else None
    
    elif field_type == 'email':
        pattern_email = r'[\w\.-]+@[\w\.-]+\.\w+'

        match_email = re.search(pattern_email, answer)

        if match_email:
            answer = match_email.group()
        else:
            answer = None
    
    elif field_type == 'phone':
        pattern_number = r'(?:(?:\+|00)92)?\s*0*3\d{2}(?:-|\s*)\d{7}'
    
        match_number = re.search(pattern_number, answer)

        if match_number:
            answer = match_number.group()
        else:
            answer = None

    return answer

# %%
validate_and_format_answer("Rs 75,000 - Rs 125,000 a month", "salary")
# Out:
# 75,000
# '75,000'

# %% [markdown]
# ## Extraction Methods

# %%
def extract_fields(context):
    # Initialize the QA model pipeline
    nlp = pipeline('question-answering', model=model_name, tokenizer=model_name)
    
    # Clean up the context text
    context = clean_text(context)
    
    extracted_data = []
    for idx, question in enumerate(questions):
        if idx == 2:
            extracted_data.append(f"{field_dict[idx]}, {context}")
        elif idx == 10:
            validated_answer = validate_and_format_answer(context, field_dict[idx])
            extracted_data.append(f"{field_dict[idx]}, {validated_answer if validated_answer else 'Unknown'}")
        elif idx == 11:
            validated_answer = validate_and_format_answer(context, field_dict[idx])
            extracted_data.append(f"{field_dict[idx]}, {validated_answer if validated_answer else 'Unknown'}")
        else:
            # Ask the model each question, providing the entire cleaned context
            result = nlp(question=question, context=context)
            answer = result['answer']
            
            # Validate and format the answer based on its type
            validated_answer = validate_and_format_answer(answer, field_dict[idx])
            
            # Store the answer, use 'Unknown' if validation failed
            extracted_data.append(f"{field_dict[idx]}: {validated_answer if validated_answer else 'Unknown'}")
        
    return extracted_data

def extract_fields2(context):
    # Initialize the QA model pipeline
    nlp = pipeline('question-answering', model=model_name, tokenizer=model_name)
    
    # Clean up the context text
    context = clean_text(context)
    
    extracted_data = []
    for idx, question in enumerate(questions2):
        print(field_dict[idx])
        if idx == 2:
            extracted_data.append(f"{field_dict[idx]}, {context}")
        elif idx == 10:
            validated_answer = validate_and_format_answer(context, field_dict[idx])
            extracted_data.append(f"{field_dict[idx]}, {validated_answer if validated_answer else 'Unknown'}")
        elif idx == 11:
            validated_answer = validate_and_format_answer(context, field_dict[idx])
            extracted_data.append(f"{field_dict[idx]}, {validated_answer if validated_answer else 'Unknown'}")
        else:
            # Ask the model each question, providing the entire cleaned context
            result = nlp(question=question, context=context)
            answer = result['answer']
            
            # Validate and format the answer based on its type
            validated_answer = validate_and_format_answer(answer, field_dict[idx])
            
            # Store the answer, use 'Unknown' if validation failed
            extracted_data.append(f"{field_dict[idx]}: {validated_answer if validated_answer else 'Unknown'}")
        
    return extracted_data

# %% [markdown]
# ## Goofy Ahh (Using multiple questions with the same context to cater wider range of scenarios)
# TODO improve Questions and Efficiency

# %%
def goofy_ahh(context):
    fields = extract_fields(context)
    context = clean_text(context)
    print('Before:')
    for i in range(len(fields)):
        print(fields[i])
    nlp = pipeline('question-answering', model=model_name, tokenizer=model_name)
    for i in  range (len(fields)):
        if "Unknown" in fields[i] and i != 2:
            result = nlp(question=questions2[i], context=context)
            validated_answer = validate_and_format_answer(result['answer'], field_dict[i])
            fields[i] = f"{field_dict[i]}: {validated_answer if validated_answer else 'Unknown'}"
    print('\nAfter:')
    return fields

# %% [markdown]
# ## Testing

# %%
context = "ibex. is looking for a Principal Linux Administrator, with strong Linux, troubleshooting, network and scripting skills, to join our Global Server Operations team. GSO is responsible for developing tools to automate and support the deployment, management, and monitoring of infrastructure. The candidate in this position will take a lead role in supporting and building these highly available and highly scalable solutions that help empower IBEX Facilities to fulfill thousands of users globally! The ideal candidate for this job has extensive IT knowledge, with previous experience as a Principle Linux Administrator, maintaining and developing solutions in a large-scale environment. Job Description: Job Specification: Bachelor's degree in Computer Science or related technical field.7 to 10 years of Linux experience and minimum 5 years of experience in Private/Public CloudEnterprise Linux - including understanding of kernel tuning and OS monitoring tools.Familiar with software project build automation (make, Maven) and Build and Integration tools (Jenkins).Proficient with scripting in Shell (bash, ksh) and Python.Working knowledge in an orchestration and configuration management tool (preferably Ansible).In-depth knowledge in public cloud (preferably AWS).Good understanding in Infrastructure and security services like Load Balancing, Firewall, TLS encryption, disk encryption etc.Good architectural experience in component placement for a traditional 3-tier application and microservices-based applications.Working experience of Linux Containerized environments (one of Open Contained Initiative, Docker, CoreOS).Extensive experience in Infrastructure as Code and automation tools (Terraform, Cloudformation, Azure Templates & DevOps)Extensive knowledge and experience in Application Containerization and Kubernetes Clusters. (EKS/AKS, ECS)Offer guidance in infrastructure movement techniques, including bulk application transfers into the cloud.Identify the top cloud architecture solutions to successfully meet the needs of the company.Lead organization through cloud adoption and establish best practices.Familiar with Networking concept on Public/Hybrid Clouds (DirectConnect/ExpressRoute /VPC/VNET,VPC Peering and etc.)Familiar with agile methodologies in Operations and Development.Able to demonstrate the ability to evaluate / measure work results in the Enterprise context.Familiarity with basic Project Management techniques to facilitate resource and workload management.Ability to manage difficult (or conflict) situations generated by daily interactions of a wide range of personalities.Strong interpersonal skills and team management proficiency.Clear vision on strategy, road to success and phases of delivery.Working in 24x7 environment."

# %%
extract_fields(context)
# Out:
# ["job_title: Bachelor's degree in Computer Science or related technical field",
#  'company_name: ibex',
# ...

# %%
extract_fields2(context)
# Out:
# job_title
# company_name
# description
# salary
# deadline
# location
# mode
# type
# sex
# experience
# email
# ["job_title: Bachelor's degree in Computer Science or related technical field",
#  'company_name: ibex',
# ...

# %%
goofy_ahh(context)
# Out:
# Before:
# job_title: Bachelor's degree in Computer Science or related technical field
# company_name: ibex
# ...

# %%
contexts[0]
# Out:
# 'Data Scientist\tHerbion Private Limited\tJob Summary: Seeking a skilled and motivated Data Scientist to join the Supply Chain Planning Department. Responsible for analyzing large datasets, developing predictive models, and optimizing supply chain processes. Collaborate with cross-functional teams to improve demand forecasting, inventory management, and overall supply chain efficiency. Strong data analysis, statistical modeling, and machine learning skills required. Job Type: Full-time Salary: Rs60,000.00 - Rs80,000.00 per month Ability to commute/relocate: Application Deadline: 30/06/2023 \tRs 60,000 - Rs 80,000 a month\t30/06/2023\tKarachi\tPhysical\tFull-time\tAll\tUnknown'

# %%
extract_fields(contexts[0])
# Out:
# ['job_title: Data Scientist',
#  'company_name: Herbion Private',
#  'description, Data Scientist Herbion Private Limited Job Summary: Seeking a skilled and motivated Data Scientist to join the Supply Chain Planning Department. Responsible for analyzing large datasets, developing predictive models, and optimizing supply chain processes. Collaborate with cross-functional teams to improve demand forecasting, inventory management, and overall supply chain efficiency. Strong data analysis, statistical modeling, and machine learning skills required. Job Type: Full-time Salary: Rs60,000.00 - Rs80,000.00 per month Ability to commute/relocate: Application Deadline: 30/06/2023 Rs 60,000 - Rs 80,000 a month 30/06/2023 Karachi Physical Full-time All Unknown',
#  'salary: Unknown',
#  'deadline: 30/06/2023',
#  'location: Karachi',
#  'mode: Physical',
#  'type: Full-time',
#  'sex: No Preference',
#  'experience: Unknown']

# %%
extract_fields2(contexts[0])
# Out:
# ['job_title: Data Scientist',
#  'company_name: Herbion',
#  'description, Data Scientist Herbion Private Limited Job Summary: Seeking a skilled and motivated Data Scientist to join the Supply Chain Planning Department. Responsible for analyzing large datasets, developing predictive models, and optimizing supply chain processes. Collaborate with cross-functional teams to improve demand forecasting, inventory management, and overall supply chain efficiency. Strong data analysis, statistical modeling, and machine learning skills required. Job Type: Full-time Salary: Rs60,000.00 - Rs80,000.00 per month Ability to commute/relocate: Application Deadline: 30/06/2023 Rs 60,000 - Rs 80,000 a month 30/06/2023 Karachi Physical Full-time All Unknown',
#  'salary: Unknown',
#  'deadline: 30/06/2023',
#  'location: Karachi',
#  'mode: Unknown',
#  'type: Full-time',
#  'sex: No Preference',
#  'experience: Unknown']

# %%
goofy_ahh(contexts[0])
# Out:
# Before:
# job_title: Data Scientist
# company_name: Herbion Private
# description, Data Scientist Herbion Private Limited Job Summary: Seeking a skilled and motivated Data Scientist to join the Supply Chain Planning Department. Responsible for analyzing large datasets, developing predictive models, and optimizing supply chain processes. Collaborate with cross-functional teams to improve demand forecasting, inventory management, and overall supply chain efficiency. Strong data analysis, statistical modeling, and machine learning skills required. Job Type: Full-time Salary: Rs60,000.00 - Rs80,000.00 per month Ability to commute/relocate: Application Deadline: 30/06/2023 Rs 60,000 - Rs 80,000 a month 30/06/2023 Karachi Physical Full-time All Unknown
# salary: Unknown
# deadline: 30/06/2023
# location: Karachi
# mode: Physical
# type: Full-time
# sex: No Preference
# experience: Unknown
#
# After:
# ['job_title: Data Scientist',
#  'company_name: Herbion Private',
# ...

# %%
test1 = 'Ossols Private Limited. is urgently looking for experienced profiles of Senior Shopify Developer. Candidate must have at least 3 years of experience (WordPress and Shopify Custom Development) and must be willing to work in NIGHT SHIFT (9 pm-6 am, Monday-Friday). Location: SMCHS Block B, Karachi. Interested candidates may share their resumes at careers@ossols.com or feel free to inbox for further details'

# %%
extract_fields(test1)
# Out:
# ['job_title: Senior Shopify Developer',
#  'company_name: Ossols Private Limited',
#  'description, Ossols Private Limited. is urgently looking for experienced profiles of Senior Shopify Developer. Candidate must have at least 3 years of experience (WordPress and Shopify Custom Development) and must be willing to work in NIGHT SHIFT (9 pm-6 am, Monday-Friday). Location: SMCHS Block B, Karachi. Interested candidates may share their resumes at careers@ossols.com or feel free to inbox for further details',
#  'salary: Unknown',
#  'deadline: Unknown',
#  'location: Karachi',
#  'mode: Unknown',
#  'type: Full-time',
#  'sex: No Preference',
#  'experience: Unknown']

# %%
extract_fields2(test1)
# Out:
# ['job_title: Senior Shopify Developer',
#  'company_name: Ossols Private Limited',
#  'description, Ossols Private Limited. is urgently looking for experienced profiles of Senior Shopify Developer. Candidate must have at least 3 years of experience (WordPress and Shopify Custom Development) and must be willing to work in NIGHT SHIFT (9 pm-6 am, Monday-Friday). Location: SMCHS Block B, Karachi. Interested candidates may share their resumes at careers@ossols.com or feel free to inbox for further details',
#  'salary: Unknown',
#  'deadline: Unknown',
#  'location: Karachi',
#  'mode: Unknown',
#  'type: Full-time',
#  'sex: No Preference',
#  'experience: 3 years']

# %%
goofy_ahh(test1)
# Out:
# Before:
# job_title: Senior Shopify Developer
# company_name: Ossols Private Limited
# description, Ossols Private Limited. is urgently looking for experienced profiles of Senior Shopify Developer. Candidate must have at least 3 years of experience (WordPress and Shopify Custom Development) and must be willing to work in NIGHT SHIFT (9 pm-6 am, Monday-Friday). Location: SMCHS Block B, Karachi. Interested candidates may share their resumes at careers@ossols.com or feel free to inbox for further details
# salary: Unknown
# deadline: Unknown
# location: Karachi
# mode: Unknown
# type: Full-time
# sex: No Preference
# experience: Unknown
#
# After:
# ['job_title: Senior Shopify Developer',
#  'company_name: Ossols Private Limited',
# ...

# %% [markdown]
# ***

# %%
test2 = 'Mod. Ventures is looking for the following positions; 1) Frontend React Native Developer 2) Backend Developer 3) Full Stack Mobile App Developer. 1 - 2 years of experience. Benefits: Competitive salary. Flexible work hours. Remote work opportunities with potential for hybrid in the future (Karachi). Collaborative and inclusive work culture. Interested candidates can apply at careers@themodventures.com. Please mention the job title in the email you are applying for.'

# %%
extract_fields(test2)
# Out:
# ['job_title: Frontend React Native Developer',
#  'company_name: Mod. Ventures',
#  'description, Mod. Ventures is looking for the following positions; 1) Frontend React Native Developer 2) Backend Developer 3) Full Stack Mobile App Developer. 1 - 2 years of experience. Benefits: Competitive salary. Flexible work hours. Remote work opportunities with potential for hybrid in the future (Karachi). Collaborative and inclusive work culture. Interested candidates can apply at careers@themodventures.com. Please mention the job title in the email you are applying for.',
#  'salary: Competitive',
#  'deadline: Unknown',
#  'location: Karachi',
#  'mode: Hybrid',
#  'type: Full-time',
#  'sex: No Preference',
#  'experience: Unknown']

# %%
extract_fields2(test2)
# Out:
# ['job_title: Frontend React Native Developer',
#  'company_name: themodventures',
#  'description, Mod. Ventures is looking for the following positions; 1) Frontend React Native Developer 2) Backend Developer 3) Full Stack Mobile App Developer. 1 - 2 years of experience. Benefits: Competitive salary. Flexible work hours. Remote work opportunities with potential for hybrid in the future (Karachi). Collaborative and inclusive work culture. Interested candidates can apply at careers@themodventures.com. Please mention the job title in the email you are applying for.',
#  'salary: Competitive',
#  'deadline: Unknown',
#  'location: Unknown',
#  'mode: Remote',
#  'type: Full-time',
#  'sex: No Preference',
#  'experience: 2 years']

# %%
goofy_ahh(test2)
# Out:
# Before:
# job_title: Frontend React Native Developer
# company_name: Mod. Ventures
# description, Mod. Ventures is looking for the following positions; 1) Frontend React Native Developer 2) Backend Developer 3) Full Stack Mobile App Developer. 1 - 2 years of experience. Benefits: Competitive salary. Flexible work hours. Remote work opportunities with potential for hybrid in the future (Karachi). Collaborative and inclusive work culture. Interested candidates can apply at careers@themodventures.com. Please mention the job title in the email you are applying for.
# salary: Competitive
# deadline: Unknown
# location: Karachi
# mode: Hybrid
# type: Full-time
# sex: No Preference
# experience: Unknown
#
# After:
# ['job_title: Frontend React Native Developer',
#  'company_name: Mod. Ventures',
# ...

# %%
test3 = 'Job Title: Flutter Developer. Job Description: We are seeking a skilled Flutter Developer with a minimum of 1 year of experience, preferably more, to join our team. The ideal candidate should possess a strong understanding of state management in Flutter applications and demonstrate proficiency in integrating APIs using methods such as GET, PUT, POST, and DELETE. Additionally, familiarity with Firebase authentication is required for this role. Key Responsibilities: Develop and maintain high-quality Flutter applications. Implement efficient state management solutions to enhance application performance. Integrate RESTful APIs into Flutter applications, ensuring smooth data exchange. Utilize various HTTP methods (GET, PUT, POST, DELETE) to interact with APIs effectively. Implement Firebase authentication for user authentication and authorization. Collaborate with cross-functional teams to define, design, and ship new features. Troubleshoot and debug application issues as they arise. Stay updated with the latest Flutter and Firebase trends, tools, and technologies. Qualifications: Bachelors degree in Computer Science, Engineering, or related field. Minimum 1 year of experience in Flutter app development. Proficiency in state management techniques such as Provider, Bloc, or Riverpod. Strong understanding of RESTful APIs and experience with API integration in Flutter. Familiarity with HTTP methods (GET, PUT, POST, DELETE) for data manipulation. Hands-on experience with Firebase authentication and Firebase services. Excellent problem-solving skills and attention to detail. Ability to work independently and in a team environment. Good communication skills and ability to collaborate effectively with team members. Preferred Qualifications: Knowledge of version control systems like Git. Experience with Agile development methodologies. Strong portfolio showcasing previous Flutter projects.'

# %%
extract_fields(test3)
# Out:
# ['job_title: Flutter Developer',
#  'company_name: Flutter Developer',
# ...

# %%
extract_fields(test3)
# Out:
# ['job_title: Flutter Developer',
#  'company_name: Flutter Developer',
# ...

# %%
goofy_ahh(test3)
# Out:
# Before:
# job_title: Flutter Developer
# company_name: Flutter Developer
# ...

# %% [markdown]
# ## Testing Random Shit

# %%
goofy_ahh(contexts[0])
# Out:
# job_title: Data Scientist
# company_name: Herbion Private
# description, Data Scientist Herbion Private Limited Job Summary: Seeking a skilled and motivated Data Scientist to join the Supply Chain Planning Department. Responsible for analyzing large datasets, developing predictive models, and optimizing supply chain processes. Collaborate with cross-functional teams to improve demand forecasting, inventory management, and overall supply chain efficiency. Strong data analysis, statistical modeling, and machine learning skills required. Job Type: Full-time Salary: Rs60,000.00 - Rs80,000.00 per month Ability to commute/relocate: Application Deadline: 30/06/2023 Rs 60,000 - Rs 80,000 a month 30/06/2023 Karachi Physical Full-time All Unknown
# salary: Rs60,000.00 - Rs80,000.00 per month
# deadline: 30/06/2023
# location: Karachi
# mode: Physical
# type: Full-time
# sex: No Preference
# experience: Unknown
# ['job_title: Data Scientist',
#  'company_name: Herbion Private',
# ...

# %%
for field in correct_answers[2]:
    print(field)
# Out:
# Data Analyst
# The Dynamics Research Consultants
# Key Responsibilities: Qualification Job Type: Full-time Salary: Rs50,000.00 - Rs80,000.00 per month Experience:
# Rs 50,000 - Rs 80,000 a month
# 23/03/2022
# Karachi
# Physical
# Full-time
# All
# 1 Year

# %%
question = questions[3]
context = contexts[2]
nlp = pipeline('question-answering', model=model_name, tokenizer=model_name)
input = {'question': question, 'context': context}
result = nlp(input)
result
# Out:
# {'score': 0.6744804382324219,
#  'start': 111,
#  'end': 146,
#  'answer': 'Rs50,000.00 - Rs80,000.00 per month'}

# %%
validate_and_format_answer("Rs50,000.00 - Rs80,000.00 per month", "salary")
# Out:
# 'Rs50,000.00 - Rs80,000.00 per month'

# %%
input = {'question': question, 'context': clean_text(context)}
result = nlp(input)
result
# Out:
# {'score': 3.563287464203313e-06, 'start': 635, 'end': 642, 'answer': 'Karachi'}

# %%
print(contexts[0])
print(clean_text(contexts[0]))
# Out:
# Data Scientist	Herbion Private Limited	Job Summary: Seeking a skilled and motivated Data Scientist to join the Supply Chain Planning Department. Responsible for analyzing large datasets, developing predictive models, and optimizing supply chain processes. Collaborate with cross-functional teams to improve demand forecasting, inventory management, and overall supply chain efficiency. Strong data analysis, statistical modeling, and machine learning skills required. Job Type: Full-time Salary: Rs60,000.00 - Rs80,000.00 per month Ability to commute/relocate: Application Deadline: 30/06/2023 	Rs 60,000 - Rs 80,000 a month	30/06/2023	Karachi	Physical	Full-time	All	Unknown
# ...

# %%
validate_and_format_answer('remote', 'mode')
# Out:
# 'Hybrid'

# %%
for i in range(len(correct_answers[0])):
    print (correct_answers[i][3])
# Out:
# Rs 60,000 - Rs 80,000 a month
# Rs 30,000 - Rs 35,000 a month
# Rs 50,000 - Rs 80,000 a month
# Rs 25,000 - Rs 30,000 a month
# Rs 40,000 - Rs 45,000 a month
# Rs 75,000 - Rs 125,000 a month
# Rs 50,000 - Rs 130,000 a month
# Unknown
# Rs 100,000 a month
# Rs 45,000 - Rs 55,000 a month

# %%
def get_fields(context):
    nlp = pipeline('question-answering', model=model_name, tokenizer=model_name)
    fields = []
    count = 0
    for question in questions:
        if count == 2:
            fields.append(f"{field_dict[count]}, {context}")
            count += 1
        else:
            input = {'question': {question},'context': context}
            result = nlp(input)
            fields.append(f"{field_dict[count]}, {result['answer']}")
            count += 1
    return fields

# %%
i = 1
get_fields(contexts[i])
# Out:
# ['job_title, Freelance Information Technology',
#  'company_name, Freelance Information Technology',
#  "description, Freelance Information Technology. (Part Time)\tMen's Wear Brand\tWEâ€™RE HIRING Freelance Information Technology. (Part Time) As an IT professional you are generally involves managing and storing data using computers, software, databases, networks, and servers. you may write programs, maintain networks, analyze systems, and provide technical support. Requirements: Education: Bachelorâ€™s Degree or equivalent experience in Computer Science, Information Technology, related field. Experience: 3-5 Years IT End User Support / Helpdesk experience Location: Korangi Industrial Area Karachi. Email: goodjobs2022@gmail.com Job Type: Part-timePart-time hours: 24 per week Salary: Rs30,000.00 - Rs35,000.00 per month Ability to Commute: Ability to Relocate: \tRs 30,000 - Rs 35,000 a month\t22/02/2023\tKarachi\tPhysical\tPart-time\tAll\t3-5 Year",
# ...

# %%
import re

# Define the regular expression patterns
pattern1 = r'\b(?:\d{1,3}(,\d{3})){1}(?:,?\d)\s?-\s?(?:\d{1,3}(,\d{3})){1}(?:,?\d)000\b'
pattern2 = r'\b\d{1,3}(,\d{3})*,?\d*000\b'
pattern3 = r'(\b\d{4,}(?=[a-zA-Z])|\b\d{5,}\b)'

# Sample texts to test the regular expression
texts = [
    "Here is a number: 60000",
    "Another number is 150,000",
    "Range: 60,000 - 100,000",
    "Invalid number: 123456789",
    "Invalid range: 2000 - 3000",
    "Valid range: 60,000 - 1,00,000",
    "Large number: 600,000",
    "Another large number: 1,234,000",
    "Consecutive numbers: 6000001000",
    "Invalid text: 60000asd",
    "Invalid text with commas: 123,000,000",
    "Another invalid text: 32401000d",
    "Number followed by a letter: 1000b",
    "find numbers here 10,000,000 - 32,000,000",
    input("Enter some shit")
]

# Iterate over each text and extract numbers ending with "000"
for text in texts:
    match1 = re.search(pattern1, text)
    match2 = re.search(pattern2, text)
    match3 = re.search(pattern3, text)
    if match1:
        print(f"Pattern 1 matched: {match1.group()} in '{text}'")
    elif match2:
        print(f"Pattern 2 matched: {match2.group()} in '{text}'")
    elif match3:
        print(f"Pattern 3 matched: {match3.group()} in '{text}'")
    else:
        print(f"No match found in '{text}'")
# Out:
# Pattern 2 matched: 60000 in 'Here is a number: 60000'
# Pattern 2 matched: 150,000 in 'Another number is 150,000'
# Pattern 2 matched: 60,000 in 'Range: 60,000 - 100,000'
# Pattern 3 matched: 123456789 in 'Invalid number: 123456789'
# Pattern 2 matched: 2000 in 'Invalid range: 2000 - 3000'
# Pattern 2 matched: 60,000 in 'Valid range: 60,000 - 1,00,000'
# Pattern 2 matched: 600,000 in 'Large number: 600,000'
# Pattern 2 matched: 1,234,000 in 'Another large number: 1,234,000'
# Pattern 2 matched: 6000001000 in 'Consecutive numbers: 6000001000'
# Pattern 3 matched: 60000 in 'Invalid text: 60000asd'
# Pattern 2 matched: 123,000,000 in 'Invalid text with commas: 123,000,000'
# Pattern 3 matched: 32401000 in 'Another invalid text: 32401000d'
# Pattern 3 matched: 1000 in 'Number followed by a letter: 1000b'
# Pattern 2 matched: 10,000,000 in 'find numbers here 10,000,000 - 32,000,000'
# No match found in 'osdinfoweiww'
